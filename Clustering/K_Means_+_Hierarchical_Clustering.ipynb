# %% [markdown]
# <a href="https://colab.research.google.com/github/SohaHussain/Machine-Learning/blob/main/Clustering/K_Means_%2B_Hierarchical_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Read and visualize the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime as dt

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

import warnings
warnings.filterwarnings("ignore")
import sys

# %%
retail_df = pd.read_csv("Online+Retail.csv", sep=",", encoding="ISO-8859-1", header=0)
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
retail_df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ## Clean the data

# %%
# missing values
round(100*(retail_df.isnull().sum())/len(retail_df), 2)
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# CustomerID     24.93
# Country         0.00
# dtype: float64

# %%
# drop all rows having missing values
retail_df = retail_df.dropna()
retail_df.shape
# Out:
# (406829, 8)

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
retail_df['amount'] = retail_df['Quantity'] * retail_df['UnitPrice']
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country  amount
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom   15.30
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom   20.34
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom   22.00
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom   20.34
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom   20.34

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# *   R (recency) - number of days since last purchase
# *   F (frequency) - number of transactions
# *   M (monetary) - tottal amount of transactions/revenue collected

# %%
# monetary
grouped_df = retail_df.groupby('CustomerID')['amount'].sum()
grouped_df = grouped_df.reset_index()
grouped_df.head()
# Out:
#    CustomerID   amount
# 0     12346.0     0.00
# 1     12347.0  4310.00
# 2     12348.0  1797.24
# 3     12349.0  1757.55
# 4     12350.0   334.40

# %%
# frequency
frequency = retail_df.groupby('CustomerID')['InvoiceNo'].count()
frequency = frequency.reset_index()
frequency.columns = ['CustomerID', 'frequency']
frequency.head()
# Out:
#    CustomerID  frequency
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
# merge the two dfs
grouped_df = pd.merge(grouped_df, frequency, on='CustomerID', how='inner')
grouped_df.head()
# Out:
#    CustomerID   amount  frequency
# 0     12346.0     0.00          2
# 1     12347.0  4310.00        182
# 2     12348.0  1797.24         31
# 3     12349.0  1757.55         73
# 4     12350.0   334.40         17

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country  amount
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom   15.30
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom   20.34
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom   22.00
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom   20.34
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom   20.34

# %%
# recency
# convert to datetime
retail_df['InvoiceDate'] = pd.to_datetime(retail_df['InvoiceDate'], 
                                          format='%d-%m-%Y %H:%M')

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34

# %%
# compute the max date
max_date = max(retail_df['InvoiceDate'])
max_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
# compute the diff
retail_df['diff'] = max_date - retail_df['InvoiceDate']
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  amount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
#
#                diff
# 0 373 days 04:24:00
# 1 373 days 04:24:00
# 2 373 days 04:24:00
# 3 373 days 04:24:00
# 4 373 days 04:24:00

# %%
# recency
last_purchase = retail_df.groupby('CustomerID')['diff'].min()
last_purchase = last_purchase.reset_index()
last_purchase.head()
# Out:
#    CustomerID              diff
# 0     12346.0 325 days 02:33:00
# 1     12347.0   1 days 20:58:00
# 2     12348.0  74 days 23:37:00
# 3     12349.0  18 days 02:59:00
# 4     12350.0 309 days 20:49:00

# %%
# merge
grouped_df = pd.merge(grouped_df, last_purchase, on='CustomerID', how='inner')
grouped_df.columns = ['CustomerID', 'amount', 'frequency', 'recency']
grouped_df.head()
# Out:
#    CustomerID   amount  frequency           recency
# 0     12346.0     0.00          2 325 days 02:33:00
# 1     12347.0  4310.00        182   1 days 20:58:00
# 2     12348.0  1797.24         31  74 days 23:37:00
# 3     12349.0  1757.55         73  18 days 02:59:00
# 4     12350.0   334.40         17 309 days 20:49:00

# %%
# number of days only
grouped_df['recency'] = grouped_df['recency'].dt.days
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency
# 0     12346.0     0.00          2      325
# 1     12347.0  4310.00        182        1
# 2     12348.0  1797.24         31       74
# 3     12349.0  1757.55         73       18
# 4     12350.0   334.40         17      309

# %% [markdown]
# ### removing outliers

# %%
plt.boxplot(grouped_df['amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc5d62f4850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc5d62f4d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc5d62f45b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc5d62dc310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc5d62dc5b0>],
#  'means': []}

# %%
plt.boxplot(grouped_df['frequency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc5d63c8d60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc5d63d92e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc5d63c8ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc5d63d9820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc5d63d9ac0>],
#  'means': []}

# %%
plt.boxplot(grouped_df['recency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc5d630c700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc5d630cc40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc5d630c460>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc5d631c1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc5d631c460>],
#  'means': []}

# %%
Q1 = grouped_df.amount.quantile(0.05)
Q3 = grouped_df.amount.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_df[(grouped_df.amount >= Q1 - 1.5*IQR) & (grouped_df.amount <= Q3 + 1.5*IQR)]

# %%
Q1 = grouped_df.recency.quantile(0.05)
Q3 = grouped_df.recency.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_df[(grouped_df.recency >= Q1 - 1.5*IQR) & (grouped_df.recency <= Q3 + 1.5*IQR)]

# %%
Q1 = grouped_df.frequency.quantile(0.05)
Q3 = grouped_df.frequency.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_df[(grouped_df.frequency >= Q1 - 1.5*IQR) & (grouped_df.frequency <= Q3 + 1.5*IQR)]

# %% [markdown]
# ### rescaling

# %%
df = grouped_df[['amount','frequency','recency']]
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_scaled.shape
# Out:
# (4293, 3)

# %%
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = ['amount', 'frequency', 'recency']
df_scaled.head()
# Out:
#      amount  frequency   recency
# 0 -0.723738  -0.752888  2.301611
# 1  1.731617   1.042467 -0.906466
# 2  0.300128  -0.463636 -0.183658
# 3  0.277517  -0.044720 -0.738141
# 4 -0.533235  -0.603275  2.143188

# %% [markdown]
# ## Modelling

# %%
# k means with arbitary k

kmeans = KMeans(n_clusters = 4, max_iter = 50)
kmeans.fit(df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([1, 0, 2, ..., 1, 2, 2], dtype=int32)

# %% [markdown]
# ### finding optimal number of clusters

# %%
# elbow curve / SSD

ssd = []
num_clusters = [2,3,4,5,6,7,8]
for clusters in num_clusters:
  kmeans = KMeans(n_clusters = clusters, max_iter=50)
  kmeans.fit(df_scaled)
  ssd.append(kmeans.inertia_)

plt.plot(ssd)

# %% [markdown]
# ### Silhouette Analysis

# %% [markdown]
# $$\text{silhouette score}=\frac{p-q}{max(p,q)}$$
#
# $p$ is the mean distance to the points in the nearest cluster that the data point is not a part of
#
# $q$ is the mean intra-cluster distance to all the points in its own cluster.
#
# * The value of the silhouette score range lies between -1 to 1.
#
# * A score closer to 1 indicates that the data point is very similar to other data points in the cluster,
#
# * A score closer to -1 indicates that the data point is not similar to the data points in its cluster.

# %%
num_clusters = [2,3,4,5,6,7,8]
for clusters in num_clusters:
  kmeans = KMeans(n_clusters = clusters, max_iter=50)
  kmeans.fit(df_scaled)
  cluster_labels = kmeans.labels_
  s_avg = silhouette_score(df_scaled,cluster_labels)
  print("For n_clusters={0}, the silhouette score is {1}".format(clusters, s_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.5415858652525395
# For n_clusters=3, the silhouette score is 0.5084896296141937
# For n_clusters=4, the silhouette score is 0.47782241003860476
# For n_clusters=5, the silhouette score is 0.46627005641897035
# For n_clusters=6, the silhouette score is 0.41742250872395564
# For n_clusters=7, the silhouette score is 0.41594981070601306
# For n_clusters=8, the silhouette score is 0.4022291320798314

# %%
# final model with k=3
kmeans = KMeans(n_clusters=3, max_iter=50)
kmeans.fit(df_scaled)
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
# assign the label
grouped_df['cluster_id'] = kmeans.labels_
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id
# 0     12346.0     0.00          2      325           2
# 1     12347.0  4310.00        182        1           0
# 2     12348.0  1797.24         31       74           1
# 3     12349.0  1757.55         73       18           1
# 4     12350.0   334.40         17      309           2

# %%
sns.boxplot(x='cluster_id', y='amount', data=grouped_df)
# Out:
# <Axes: xlabel='cluster_id', ylabel='amount'>

# %%
sns.boxplot(x='cluster_id', y='frequency', data=grouped_df)
# Out:
# <Axes: xlabel='cluster_id', ylabel='frequency'>

# %%
sns.boxplot(x='cluster_id', y='recency', data=grouped_df)
# Out:
# <Axes: xlabel='cluster_id', ylabel='recency'>

# %% [markdown]
# ## Hierarchical Clustering

# %%
df_scaled.head()
# Out:
#      amount  frequency   recency
# 0 -0.723738  -0.752888  2.301611
# 1  1.731617   1.042467 -0.906466
# 2  0.300128  -0.463636 -0.183658
# 3  0.277517  -0.044720 -0.738141
# 4 -0.533235  -0.603275  2.143188

# %%
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id
# 0     12346.0     0.00          2      325           2
# 1     12347.0  4310.00        182        1           0
# 2     12348.0  1797.24         31       74           1
# 3     12349.0  1757.55         73       18           1
# 4     12350.0   334.40         17      309           2

# %%
# single linkage
sys.setrecursionlimit(100000)
m = linkage(df_scaled,method="single",metric='euclidean')
dendrogram(m)
plt.show()

# %%
# complete linkage

sys.setrecursionlimit(100000)
m = linkage(df_scaled, method='complete', metric='euclidean')
dendrogram(m)
plt.show()

# %%
# 3 clusters
cluster_labels = cut_tree(m, n_clusters=3).reshape(-1, )
cluster_labels
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
# assign cluster labels
grouped_df['cluster_labels'] = cluster_labels
grouped_df.head()
# Out:
#    CustomerID   amount  frequency  recency  cluster_id  cluster_labels
# 0     12346.0     0.00          2      325           2               0
# 1     12347.0  4310.00        182        1           0               1
# 2     12348.0  1797.24         31       74           1               0
# 3     12349.0  1757.55         73       18           1               0
# 4     12350.0   334.40         17      309           2               0

# %%
sns.boxplot(x='cluster_labels', y='recency', data=grouped_df)
# Out:
# <Axes: xlabel='cluster_labels', ylabel='recency'>

# %%
sns.boxplot(x='cluster_labels', y='frequency', data=grouped_df)
# Out:
# <Axes: xlabel='cluster_labels', ylabel='frequency'>

# %%
sns.boxplot(x='cluster_labels', y='amount', data=grouped_df)
# Out:
# <Axes: xlabel='cluster_labels', ylabel='amount'>
